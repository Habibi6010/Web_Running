# %%
from flask import Flask, jsonify, request, render_template,send_from_directory
from flask_cors import CORS
import json
from drawing import drawing
import cv2
import threading
import os
import pandas as pd
import urllib.parse
from Analysis_Landmarks_Pusture import Analysis_Landmarks
from supabase import create_client, Client
import datetime
import requests
from tools import tools
import math

# %%
cap = cv2.VideoCapture(r"C:\Users\mxh220053\Desktop\Web_Running\python\received_videos\test@gmail.com_test_video.MOV")
drawing_object = drawing()
frame_landmarks = []
frame_number = 0
selected_model='yolo'

while True:
        ret, frame = cap.read()
        if not ret:
                break
        frame_number += 1
        landmarks = None
        if selected_model == 'yolo':
                yolo_landmarks, _ = drawing_object.yolo_landmark_detection(frame)
                if len(yolo_landmarks) > 0:
                        # If multiple people, take the first
                        landmarks = yolo_landmarks[0]
        elif selected_model == 'mediapipe':
                mediapipe_landmarks = drawing_object.mediapipe_landmark_detection(frame)
                if mediapipe_landmarks and len(mediapipe_landmarks) > 0:
                        landmarks = mediapipe_landmarks
        # Store landmarks or None
        frame_landmarks.append({
                'frame': frame_number,
                'landmarks': landmarks if landmarks is not None else None
        })

cap.release()
# Out:
# 0: 384x640 2 persons, 189.9ms
# Speed: 1.7ms preprocess, 189.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.4ms
# Speed: 1.3ms preprocess, 156.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 192.4ms
# Speed: 1.2ms preprocess, 192.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 149.8ms
# Speed: 1.2ms preprocess, 149.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.1ms
# Speed: 1.1ms preprocess, 164.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 143.8ms
# Speed: 1.2ms preprocess, 143.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.6ms
# Speed: 1.0ms preprocess, 151.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.8ms
# Speed: 0.9ms preprocess, 158.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 146.8ms
# Speed: 1.0ms preprocess, 146.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.1ms
# Speed: 1.1ms preprocess, 158.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.3ms
# Speed: 1.0ms preprocess, 147.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.1ms
# Speed: 1.2ms preprocess, 162.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.4ms
# Speed: 1.2ms preprocess, 156.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.4ms
# Speed: 1.2ms preprocess, 162.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.1ms
# Speed: 1.0ms preprocess, 168.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.1ms
# Speed: 1.1ms preprocess, 155.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.7ms
# Speed: 1.1ms preprocess, 152.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      12 landmarks = None
#      13 if selected_model == 'yolo':
# ---> 14         yolo_landmarks, _ = drawing_object.yolo_landmark_detection(frame)
#      15         if len(yolo_landmarks) > 0:
#      16                 # If multiple people, take the first
#      17                 landmarks = yolo_landmarks[0]
#
# File c:\Users\mxh220053\Desktop\Web_Running\python\drawing.py:36, in drawing.yolo_landmark_detection(self, frame)
#      33 def yolo_landmark_detection(self, frame):
#      34
#      35     # YOLO Detection
# ---> 36     yolo_pose_result = self.yolo_model(frame)
#      37     yolo_landmarks = yolo_pose_result[0].keypoints.data.cpu(
#      38     ).numpy().astype(float)
#      39     yolo_boxs = yolo_pose_result[0].boxes.data.cpu().numpy().astype(float)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)
#     180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\engine\model.py:560, in Model.predict(self, source, stream, predictor, **kwargs)
#     558 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559     self.predictor.set_prompts(prompts)
# --> 560 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\engine\predictor.py:175, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     173     return self.stream_inference(source, model, *args, **kwargs)
#     174 else:
# --> 175     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\engine\predictor.py:261, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     259 # Inference
#     260 with profilers[1]:
# --> 261     preds = self.inference(im, *args, **kwargs)
#     262     if self.args.embed:
#     263         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\engine\predictor.py:145, in BasePredictor.inference(self, im, *args, **kwargs)
#     139 """Runs inference on a given image using the specified model and arguments."""
#     140 visualize = (
#     141     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     142     if self.args.visualize and (not self.source_type.tensor)
#     143     else False
#     144 )
# --> 145 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\autobackend.py:557, in AutoBackend.forward(self, im, augment, visualize, embed)
#     555 # PyTorch
#     556 if self.pt or self.nn_module:
# --> 557     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     559 # TorchScript
#     560 elif self.jit:
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\tasks.py:114, in BaseModel.forward(self, x, *args, **kwargs)
#     112 if isinstance(x, dict):  # for cases of training and validating while training.
#     113     return self.loss(x, *args, **kwargs)
# --> 114 return self.predict(x, *args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\tasks.py:132, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     130 if augment:
#     131     return self._predict_augment(x)
# --> 132 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\tasks.py:153, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     151 if profile:
#     152     self._profile_one_layer(m, x, dt)
# --> 153 x = m(x)  # run
#     154 y.append(x if m.i in self.save else None)  # save output
#     155 if visualize:
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\modules\block.py:239, in C2f.forward(self, x)
#     237 """Forward pass through C2f layer."""
#     238 y = list(self.cv1(x).chunk(2, 1))
# --> 239 y.extend(m(y[-1]) for m in self.m)
#     240 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\modules\block.py:239, in <genexpr>(.0)
#     237 """Forward pass through C2f layer."""
#     238 y = list(self.cv1(x).chunk(2, 1))
# --> 239 y.extend(m(y[-1]) for m in self.m)
#     240 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\modules\block.py:348, in Bottleneck.forward(self, x)
#     346 def forward(self, x):
#     347     """Applies the YOLO FPN to input data."""
# --> 348     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\ultralytics\nn\modules\conv.py:55, in Conv.forward_fuse(self, x)
#      53 def forward_fuse(self, x):
#      54     """Apply convolution and activation without batch normalization."""
# ---> 55     return self.act(self.conv(x))
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\mxh220053\.conda\envs\Running\lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
text=r'C:\Users\mxh220053\Desktop\Web_Running\python\received_videos\test@gmail.com_test_video.MOV'
filename = os.path.basename(text)  # 'test@gmail.com_test_video.MOV'
print(filename)
name_without_ext = os.path.splitext(text)  # 'test@gmail.com_test_video'
print(name_without_ext)
# Out:
# test@gmail.com_test_video.MOV
# ('C:\\Users\\mxh220053\\Desktop\\Web_Running\\python\\received_videos\\test@gmail.com_test_video', '.MOV')
